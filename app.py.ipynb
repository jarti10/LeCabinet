# %%
pip install streamlit
# Out:
# ...
#   Using cached click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# ...
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ----------------------- ---------------- 5.8/9.8 MB 32.0 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 30.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/731.2 kB ? eta -:--:--
#    --------------------------------------- 731.2/731.2 kB 15.1 MB/s eta 0:00:00
# ...
# Using cached click-8.1.8-py3-none-any.whl (98 kB)
# ...
#    ---------------------------------------- 0.0/25.3 MB ? eta -:--:--
#    ---------- ----------------------------- 6.8/25.3 MB 34.9 MB/s eta 0:00:01
#    ------------------------ --------------- 15.2/25.3 MB 36.8 MB/s eta 0:00:01
#    ------------------------------------ --- 23.1/25.3 MB 37.4 MB/s eta 0:00:01
#    ---------------------------------------- 25.3/25.3 MB 32.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/6.9 MB ? eta -:--:--
# ...

# %%
import streamlit as st
from datetime import date

st.set_page_config(page_title="Reserva Clase de Barre", layout="centered")

st.title("🩰 Reserva tu Clase de Barre")

st.markdown("Por favor, completa el formulario para reservar tu clase:")

# Formulario
with st.form("form_reserva"):
    nombre = st.text_input("Nombre completo")
    correo = st.text_input("Correo electrónico")
    fecha = st.date_input("Fecha de la clase", min_value=date.today())
    horario = st.selectbox("Horario preferido", ["Mañana", "Tarde"])
    nivel = st.radio("Nivel de experiencia", ["Principiante", "Intermedio", "Avanzado"])

    enviado = st.form_submit_button("Reservar")

    if enviado:
        if nombre and correo:
            st.success(f"¡Gracias, {nombre}! Tu clase de barre ha sido reservada para el {fecha} en horario de {horario.lower()}.")
        else:
            st.error("Por favor, completa todos los campos obligatorios.")
